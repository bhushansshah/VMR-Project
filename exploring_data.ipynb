# %%
import os
import numpy as np

# %%
DATASET_PATH = '/media/bhushan/Deven/VMR Project/QVHighlight/features/'

# %%
print(os.listdir(os.path.join(DATASET_PATH, 'clip_features')))
# Out:
# ['HKotWqbcUds_360.0_510.0.npz', '--a6qL3eL0c_210.0_360.0.npz', '--a6qL3eL0c_360.0_510.0.npz', '--a6qL3eL0c_510.0_660.0.npz', '--a6qL3eL0c_60.0_210.0.npz', '--a6qL3eL0c_660.0_810.0.npz', '--d84Ars5ng_210.0_360.0.npz', '--d84Ars5ng_360.0_510.0.npz', '--d84Ars5ng_60.0_210.0.npz', '--ePzhMQU1w_210.0_360.0.npz', '--ePzhMQU1w_360.0_510.0.npz', '--ePzhMQU1w_60.0_210.0.npz', '--euWZ-mcOg_210.0_360.0.npz', '--euWZ-mcOg_360.0_510.0.npz', '--euWZ-mcOg_510.0_660.0.npz', '--euWZ-mcOg_660.0_810.0.npz', '-0F1uov8xBY_60.0_210.0.npz', '-4Mlqc7PbZY_210.0_360.0.npz', '-4Mlqc7PbZY_360.0_510.0.npz', '-4Mlqc7PbZY_510.0_660.0.npz', '-4Mlqc7PbZY_60.0_210.0.npz', '-7ECtLfnZDE_210.0_360.0.npz', '-7ECtLfnZDE_360.0_510.0.npz', '-7ECtLfnZDE_510.0_660.0.npz', '-7ECtLfnZDE_60.0_210.0.npz', '-7ECtLfnZDE_660.0_810.0.npz', '-8Aqoht56yc_210.0_360.0.npz', '-8Aqoht56yc_360.0_510.0.npz', '-8Aqoht56yc_510.0_660.0.npz', '-9kaxJa1CCo_60.0_210.0.npz', '-Av_T88Gb_I_210.0_360.0.npz', '-Av_T88Gb_I_360.0_510.0.npz', '-Av_T88Gb_I
# ...

# %%
file2 = np.load(os.path.join(DATASET_PATH, 'clip_features', 'HKotWqbcUds_360.0_510.0.npz'))
b = file2.get('features')
b.shape
# Out:
# (75, 512)

# %%
#count the no. of files in clip_features, clip_text_features, pann_features, slowfast_features

print(len(os.listdir(os.path.join(DATASET_PATH, 'clip_features'))))
print(len(os.listdir(os.path.join(DATASET_PATH, 'clip_text_features'))))
print(len(os.listdir(os.path.join(DATASET_PATH, 'pann_features'))))
print(len(os.listdir(os.path.join(DATASET_PATH, 'slowfast_features'))))
# Out:
# 12562
# 10311
# 10148
# 12562
